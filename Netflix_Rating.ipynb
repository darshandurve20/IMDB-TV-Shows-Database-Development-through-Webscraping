# %% [markdown]
# ## Import Pandas and Load the CSV file into a dataframe

# %%
import pandas as pd

#Load the csv file into a data frame
NetflixShows = pd.read_csv('Netflix_Shows.csv', encoding='cp437')

NetflixShows.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
#Check null values
NetflixShows.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
#Ccheck duplicates
NetflixShows.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 970     True
# 971     True
# 972    False
# 973    False
# 974     True
# 975     True
# 976    False
# 977    False
# 978    False
# 979    False
# 980     True
# 981    False
# 982     True
# 983     True
# 984     True
# 985    False
# 986     True
# 987    False
# 988     True
# 989    False
# 990     True
# 991     True
# 992     True
# 993    False
# 994    False
# 995     True
# 996     True
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
#Drop duplicates
NetflixShows = NetflixShows.drop_duplicates

# %%
NetflixShows['user rating score'].mean()

NetflixShows.fillna(NetflixShows.mean())
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
#Replace null values in user rating score with mean user rating score
NetflixShows['user rating score'] = NetflixShows['user rating score'].fillna(NetflixShows['user rating score'].mean())

#rename title to tv_show_names
NetflixShows = NetflixShows.rename(columns={'title': 'tv_show_name'})
NetflixShows.head()
# Out:
#             tv_show_name rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004          82.000000                80
# 1          2006          84.094215                82
# 2          2016          98.000000                80
# 3          2008          98.000000                80
# 4          2014          94.000000                80

# %% [markdown]
# ## Load the cleaned data to CSV

# %%
NetflixShows.to_csv('TVDB_Netflix_Ratings.csv')
